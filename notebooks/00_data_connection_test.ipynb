# %%
import pandas as pd
import yfinance as yf

print("✅ Environment ready!")
print("Pandas version:", pd.__version__)
# Out:
# ✅ Environment ready!
# Pandas version: 2.3.3

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Test data pull
ticker = "AAPL"
data = yf.download(ticker, period="1y")

# Preview data
data.head()
# Out:
# C:\Users\bufft\AppData\Local\Temp\ipykernel_20904\2853430131.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period="1y")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-10-21  235.384521  235.752818  233.363927  233.363927  36254500
# 2024-10-22  234.767395  235.125728  231.522502  232.806520  38846600
# 2024-10-23  229.691010  234.050724  226.704907  232.995637  52287000
# 2024-10-24  229.501892  229.750734  227.351895  228.914614  31109500
# 2024-10-25  230.337997  232.139610  228.506525  228.675736  38802300

# %%
data = yf.download("AAPL", period="1mo")
data.head()
# Out:
# C:\Users\bufft\AppData\Local\Temp\ipykernel_20904\3594504655.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", period="1mo")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2025-09-22  256.079987  256.640015  248.119995  248.300003  105517400
# 2025-09-23  254.429993  257.339996  253.580002  255.880005   60275200
# 2025-09-24  252.309998  255.740005  251.039993  255.220001   42303700
# 2025-09-25  256.869995  257.170013  251.710007  253.210007   55202100
# 2025-09-26  255.460007  257.600006  253.779999  254.100006   46076300
